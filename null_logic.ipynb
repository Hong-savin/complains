# %%
import pandas as pd

complaints_df = pd.read_csv("C:/Users/홍사빈/Desktop/archive/complaints.csv", low_memory=False)

# %%
complaints_df.shape
# Out:
# (4496055, 18)

# %%
complaints_df.head()
# Out:
#   Date received                                            Product  \
# 0    2023-12-09  Credit reporting or other personal consumer re...
# 1    2023-12-09  Credit reporting or other personal consumer re...
# 2    2023-12-09                                           Mortgage
# 3    2023-12-05                                    Debt collection
# 4    2024-01-03  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting                        Improper use of your report
# 2      FHA mortgage  Applying for a mortgage or refinancing an exis...
# 3     I do not know                  Attempts to collect debt not owed
# 4  Credit reporting  Problem with a company's investigation into an...
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# ...

# %%
complaints_df.head()
# Out:
#   Date received                                            Product  \
# 0    2023-12-09  Credit reporting or other personal consumer re...
# 1    2023-12-09  Credit reporting or other personal consumer re...
# 2    2023-12-09                                           Mortgage
# 3    2023-12-05                                    Debt collection
# 4    2024-01-03  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting                        Improper use of your report
# 2      FHA mortgage  Applying for a mortgage or refinancing an exis...
# 3     I do not know                  Attempts to collect debt not owed
# 4  Credit reporting  Problem with a company's investigation into an...
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# ...

# %%
complaints_df['Consumer complaint narrative'] = complaints_df['Consumer complaint narrative'].apply(lambda x: 'None' if pd.isna(x) else x)

# %%
complaints_df['Sub-product'] = complaints_df['Sub-product'].apply(lambda x: 'I do not know' if pd.isna(x) else x)

# %%
complaints_df['Sub-issue'] = complaints_df['Sub-issue'].apply(lambda x: 'unknown' if pd.isna(x) else x)

# %%
complaints_df['Company public response'] = complaints_df['Company public response'].apply(lambda x: 'None' if pd.isna(x) else x)

# %%
complaints_df['ZIP code'] = complaints_df['ZIP code'].apply(lambda x: 'unknown' if pd.isna(x) else x)

# %%
complaints_df['Tags'] = complaints_df['Tags'].apply(lambda x: 'unknown' if pd.isna(x) else x)

# %%
complaints_df.shape
# Out:
# (4496055, 18)

# %%
complaints_df['Consumer consent provided?'] = complaints_df['Consumer consent provided?'].apply(lambda x: 'unknown' if pd.isna(x) else x)

# %%
complaints_df['Consumer disputed?'] = complaints_df['Consumer disputed?'].apply(lambda x: 'unknown' if pd.isna(x) else x)

# %%
complaints_df['Company response to consumer'] = complaints_df['Company response to consumer'].apply(lambda x: 'None' if pd.isna(x) else x)

# %%
complaints_df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
complaints_df.head()
# Out:
#   Date received                                            Product  \
# 0    2023-12-09  Credit reporting or other personal consumer re...
# 1    2023-12-09  Credit reporting or other personal consumer re...
# 2    2023-12-09                                           Mortgage
# 3    2023-12-05                                    Debt collection
# 4    2024-01-03  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting                        Improper use of your report
# 2      FHA mortgage  Applying for a mortgage or refinancing an exis...
# 3     I do not know                  Attempts to collect debt not owed
# 4  Credit reporting  Problem with a company's investigation into an...
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# ...

# %%
complaints_df.to_csv('C:/Users/홍사빈/Desktop/archive/modified_data.csv', index=False)
